# %%
import lxml
import lxml.etree
import os.path
import json
export_dir = "h5p_export"
moodle_dir = "CommonSenseEcon.mbz-expanded/"
h5p_template_dirs = {
    "CoursePresentation" : "H5P_CoursePresentation-template",
}
h5p_assets_url_base = "/assets/workspace/"

# %%
# credit: http://pythoncentral.io/how-to-recursively-copy-a-directory-folder-in-python/ 
import errno
import shutil
import re
 
def copy(src, dest):
    try:
        shutil.copytree(src, dest)
    except OSError as e:
        # If the error was caused because the source wasn't a directory
        if e.errno == errno.ENOTDIR:
            shutil.copy(src, dest)
        else:
            print('Directory not copied. Error: %s' % e)
            
def unescape_html(s):
    s = s.replace("&lt;", "<")
    s = s.replace("&gt;", ">")
    s = s.replace("&amp;", "&")
    return s

import urllib2
filesxml = lxml.etree.parse(os.path.join(moodle_dir,"files.xml"))
def download_link_target(url,basedir,content_type="files",force=False):
    content_dir = os.path.join("content",content_type)
    dn = os.path.join(basedir,content_dir)
    if not os.path.exists(dn):
        os.makedirs(dn)
    fn = os.path.basename(url)
    dst = os.path.join(dn,fn)
    print "XXX dst = %s" % dst
    if not os.path.exists(dst) or force:
        urlinfo = urllib2.urlparse.urlparse(url)
        if urlinfo.scheme == "":
            # Look up contentHash associated with fn in files.xml
            # copy files/ab/abcd1234..., rename to fn
            fn = os.path.basename(url)
            mdlfn = filesxml.xpath("//file[filename='%s']" % fn)[0].findtext("contenthash")
            src = os.path.join(moodle_dir,"files",mdlfn[0:2],mdlfn)
            print "XXX Copying %s TO %s" % (src,dst)
            copy(src,dst)
        else:
            print "XXX Downloading %s TO %s" % (url,dst)
            open(dst, "w").write(urllib2.urlopen(url).read())
    else:
        print "XXX Skipping '%s', which already exists" % dst
    # Return an absolute URL that should work for this file within funzo
    return "/".join(h5p_assets_url_base,content_dir,fn)

import subprocess
def download_video(url,basedir,content_type="files"):
    content_dir = os.path.join("content",content_type)
    dn = os.path.join(basedir,content_dir)
    if not os.path.exists(dn):
        os.makedirs(dn)      
    urlinfo = urllib2.urlparse.urlparse(url)
    fn = "-".join([urlinfo.netloc] + urlinfo.path.split("/"))
    dst = os.path.join(dn,fn)
    print "***\nDOWNLOADING VIDEO AT %s\n***" % url
    try:
        cmd = ["youtube-dl", "--max-downloads 1", "-o " + dst, url]
        print "XXX Running %s" % " ".join(cmd)
        out = subprocess.check_output(cmd)
        print out+"\n"
    except subprocess.CalledProcessError, e:
        print "XXX ERROR %s: %s" % (e.returncode,e.output)
    return os.path.join(h5p_assets_url_base,content_dir,fn)

# %%
class _MoodleContent(object):
    contentType = None
    # Properties from moodle_backup.xml
    _base_property_names = ["sectionid","title","directory"]
    # Properties from <mod_type_dir>/<mod_id>/<mod_type>.xml
    _extended_property_names = []
    # Properties that contain HTML
    _content_nodes = []
    
    def __init__(self,xmltree):
        self._children = None
        self.root_xmltree = xmltree
        for p in self._base_property_names:
            setattr(self, p, self.root_xmltree.find(p).text)
        self._set_extended_properties()
        
    def _set_extended_properties(self):
        if len(self._extended_property_names) == 0:
            return
        sourcefn = moodle_dir + "%s/%s.xml" % (self.directory,self.contentType)
        sourcexml = lxml.etree.parse(sourcefn).xpath("//activity/" + self.contentType)[0]
        for p in self._extended_property_names:
            content = sourcexml.find(p).text
            print "XXX Setting self.%s to %s" % (p,content)
            setattr(self, p, content)
        
    def __repr__(self):
        title = self.contentType
        if hasattr(self,"title"):
            title += " %s" % self.title
        elif hasattr(self,"name"):
            title += " %s" % self.name
        lines = []
        lines.append(title)
        for m in self.children:
            lines.append("    %s" % m)
        return "\n".join(lines)
    
    @property
    def children(self):
        if self._children is None:
            self._children = self._get_children()
        return self._children  
    
    def _get_children(self):
        return []
    
    def fetch_media(self,baseDir,recursive=True):
        fetched_files = []
        for n in self._content_nodes:
            content = getattr(self,n,None)
            if content is None:
                continue
            content_xmltree = lxml.etree.HTML("<html>%s</html>" % content)
            (files,revised_xmltree) = self._fetch_media(baseDir,content_xmltree)
            
            # The above probably updated link targets, so we 
            # need to update the stored xmltree. To do this, we must
            # strip out the <html><body> that was added to the original
            # self.content to make it parseable by lxml
            revised_content = ""
            for e in revised_xmltree[0][:]:
                revised_content += lxml.etree.tostring(e)
            setattr(self,n,revised_content)
            
            fetched_files += files
        if recursive:
            for c in self.children:
                fetched_files += c.fetch_media(baseDir=baseDir,recursive=recursive)
        return fetched_files
    
    def _fetch_media(self,baseDir,content_xmltree):
        download_extensions = ("png","jpg","docx","pdf","png","mp3","mp4")
        files = []
        if content_xmltree is None:
            return files
        for a in content_xmltree.xpath("//a[@href]"):
            url = a.get("href")
            ext = os.path.splitext(url)[-1]
            if ext in download_extensions:
                local_fn = download_link_target(url,baseDir)
                a.set("href",local_fn)
                files.append(local_fn)
            
            elif getattr(self,"title",None) is not None:
                if self.title.startswith("Watch:"):
                    local_fn = download_video(url,baseDir)
                    a.set("href",local_fn)
                    files.append(local_fn)
        return (files,content_xmltree) 
    
    def to_h5p(self):
        return self._h5pClass(self)
    

class MoodleSection(_MoodleContent):
    contentType = "section"
    _base_properties = ["sectionid","title","directory"]
    _extended_properties = ["summary"]
    _content_nodes = ["summary"]
    _h5pClass = H5PCoursePresentation

    def _get_children(self):
        children = []
        # Note: "//" causes this search to start from the passed <section>'s
        #       xml root (top-level parent).
        for axml in self.root_xmltree.xpath("//activities/activity[sectionid = %s]" % self.sectionid):
            try:
                mod = module_factory(axml)
            except UnknownMoodleModuleException,e:
                print "\n***\n%s\n***\n" % e
                mod = _MoodleModule(axml)
            children.append(mod)
        return children
            
            
class _MoodleModule(_MoodleContent):
    _base_property_names = _MoodleContent._base_property_names + ["moduleid","modulename"]
    _h5pClass = H5PSlide
    
    @property
    def contentType(self):
        return self.modulename
    
class MoodlePage(_MoodleModule):
    _extended_property_names = ["intro","content"]
    _content_nodes = ["intro","content"]

class MoodleLabel(_MoodleModule):
    _extended_property_names = ["name","intro"]
    _content_nodes = ["intro"]

# TODO
class MoodleAssign(_MoodleModule):
    _extended_property_names = ["name","intro"]
    _content_nodes = ["intro"]

class MoodleFolder(_MoodleModule):
    pass

class MoodleForum(_MoodleModule):
    # Ignore these for online standalone course?
    pass

class MoodleQuiz(_MoodleModule):
    _extended_property_names = ["name","intro"]
    _content_nodes = ["intro"]

class MoodleUrl(_MoodleModule):
    _extended_property_names = ["name","intro", "externalurl"]
    _content_nodes = ["intro"]

# %%
e = lxml.etree.parse(moodle_dir + "moodle_backup.xml")
s = MoodleSection(e.xpath("//sections/section")[1])
print str(s)
#s.fetch_media("/tmp/foo")
s._content_nodes
s.title
# Out:
# XXX Setting self.intro to <p>&nbsp;</p>
# XXX Setting self.content to <p><strong><br></strong></p><p><strong><img src="@@PLUGINFILE@@/CSE_1000_course_banner_v1_Bb.jpg" alt="" width="640" height="84" role="presentation" style="vertical-align:text-bottom; margin: 0 .5em;"></strong></p><p><strong>Objectives:&nbsp; </strong><span>As soon as possible</span><span>, begin your educational journey.&nbsp; Watch two videos to get an overview of the course, what to expect to learn about the economic way of thinking and why it matters.&nbsp; Common Sense Economics or </span><span><span><a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/cse-intro-aei-secret-to-happiness" target="_blank">CSE Intro AEI- Secret to happiness</a>&nbsp;</span></span><span>(16:40 minutes) and </span><span><a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/pt0_i01_overview_tr" target="_blank"><span>Introduction to Common Sense Economics for Life Trailer</span></a></span><span>(2:43) provide a broad overview about how this course can help you and others make purposeful choices and, by doing so, help fuel prosperity and higher standards of living.</span></p>
# XXX Setting self.name to Start Line: Survey of Economic Reasoning
# XXX Setting self.intro to Start Line: Survey of Economic Reasoning
# XXX Setting self.name to Start Line: CSE 1001 Survey of Economic Reasoning
# XXX Setting self.intro to <p><strong style="font-weight: bold; color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 13px; font-style: normal; font-variant: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);">Complete this bonus activity</strong><span style="color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 13px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(255, 255, 255);">.
#  No preparation is needed. The "Survey&nbsp;of Economic Reasoning” and your
# answers to questions simply help establish a start line for your
# educational journey. Before entering the survey,&nbsp;understand that you
# have up to 30 minutes to complete it from start to finish. Please save
# each answer or response prior to advancing. There are 20 multiple choice
#  questions.</span><span style="color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 13px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(255, 255, 255);">You will earn 0.5 extra credit points for each correct answer. Work early and strategically.</span></p>
# XXX Setting self.name to Start Line: CSE 1002 Survey of Economic Reasoning
# XXX Setting self.intro to <p><strong style="font-weight: bold; color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 13px; font-style: normal; font-variant: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);">Complete this bonus activity</strong><span style="color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 13px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(255, 255, 255);">. No preparation is needed. The "Survey&nbsp;of Economic Reasoning” and your answers to questions simply help establish a start line for your educational journey. Before entering the survey,&nbsp;understand that you have up to 30 minutes to complete it from start to finish. Please save each answer or response prior to advancing. There are 20 multiple choice questions. You will earn 0.5 extra credit points for each correct answer. Work early and strategically.</span></p>
# XXX Setting self.intro to None
# XXX Setting self.content to <p><span style="font-size:medium;"><strong>Background of the Common Sense Economics for Life</strong></span></p>
# <p><span style="font-size:medium;">During the past decade, the Stavros Center for Economic Education of Florida State University has worked with a team of master economic educators to develop the Common Sense Economics for Life course. The primary contributors to this project include James Gwartney and Joe Calhoun (Florida State University), Tawni Ferrarini (Northern Michigan University), Mark Schug (University of Wisconsin—Milwaukee), John Morton (Arizona Council for Economic Education), and John Kessler (Indiana University-Purdue University Fort Wayne). The developers have all spent their careers in education and most currently direct Centers of Economic Education. They have combined their expertise to achieve a single objective: the development and implementation of an exciting and understandable set of materials that focuses on what students really need to know about economics and personal finance.</span></p>
# <p><span style="font-size:medium;">The Common Sense Economics for Life course pairs the economics primer <em>Common Sense Economics: What Everyone Should Know about Wealth and Prosperity</em> (St. Martin’s Press, 2010) by Gwartney, Stroup, Lee, and Ferrarini with short video clips, classic readings, interesting podcasts, and practical assignments. The “read, watch, listen, and do” approach is used to make learning both easy and fun. The Stavros Center now offers this multi-media course regularly online and shares the materials with individuals throughout the U.S. and now around the globe.</span></p>
# <p><span style="font-size:medium;">This course is designed for individuals who want to learn economics in an engaging fashion. All of the videos, readings, audios, and other materials needed for the course can be accessed through Canvas. The <em>Common Sense Economics</em> (2010) textbook is available at both <a class="external" href="http://www.barnesandnoble.com/w/common-sense-economics-james-d-gwartney/1100355853" target="_blank">BarnesandNoble.com</a> and <a class="external" href="http://www.amazon.com/Common-Sense-Economics-Everyone-Prosperity/dp/0312644892/ref=sr_1_1?ie=UTF8&qid=1413251007&sr=8-1&keywords=common+sense+economics+2010" target="_blank">Amazon.com</a> for approximately $15. <br /></span></p>
# <p><span style="font-size:medium;">The members of the Common Sense Economics for Life team recognize that the delivery of education is changing rapidly as innovative technology makes learning packages readily available to wider audiences at a relatively low cost. We want to lead this cutting edge change. Using multi-media technologies, our goal is to help individuals understand the economic way of thinking, how to use it to make healthy and wealthy decisions, and help economies grow and develop through sound principles of economics and personal finance. This course involves the pursuit of that goal.</span></p>
# <p><span style="font-size:medium;">This course is divided into 16 modules and four (4) parts: (1) key elements of the economic way of thinking, (2) the institutional environment for growth and prosperity, (3) economics and the role of government, and (4) personal finance. Each focuses on the things people need to know to live a more fulfilling life. Let’s get started.</span></p>
# <p><span style="font-size:medium;">Enjoy the following videos to get an overview of why you should complete this course!</span></p>
# <ol><li><span style="font-size:medium;"><a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/cse-intro-aei-secret-to-happiness" target="_blank">Common Sense Economics Intro AEI- Secret to happiness<span class="screenreader-only"> (Links to an external site.)</span></a> (16:35);</span></li>
# <li><span style="font-size:medium;"><a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/pt0_i00_course_intro" target="_blank">Common Sense Economics Slice of Life Introduction Video 0<span class="screenreader-only"> (Links to an external site.)</span></a> (2:08); and</span></li>
# <li><span style="font-size:medium;"><a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/pt0_i03_author_tr" target="_blank">Common Sense Economics for Life Author trailer<span class="screenreader-only"> (Links to an external site.)</span></a> (6:49).</span></li>
# </ol>
# XXX Setting self.intro to <p>&nbsp;</p>
# XXX Setting self.content to <p><span><span style="color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 14px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; display: inline !important; float: none; background-color: rgb(255, 255, 255);">These three videos provide a broad overview about how this course can help you and others make purposeful choices and, by doing so, help fuel prosperity and higher standards of living.</span></span></p>
# <ol style="padding: 0px; margin: 0px 0px 10px 2.5em; color: rgb(51, 51, 51); font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 14px; font-style: normal; font-variant: normal; font-weight: normal; letter-spacing: normal; line-height: 20px; orphans: auto; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 1; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: rgb(255, 255, 255);"><li>
# <a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/cse-intro-aei-secret-to-happiness-1/video_view" target="_blank">Common Sense Economics&nbsp;(CSE) Intro AEI- Secret to happiness</a>&nbsp;(16:23 minutes); and</li>
# <li>
# <a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/pt0_i01_overview_tr" target="_blank"><span><span>Introduction to Common Sense Economics for Life Trailer</span></span></a>(2:43)</li><li><a class="external" href="http://www.criticalcommons.org/Members/fsustavros/clips/pt0_i03_author_tr" target="_blank">Common Sense Economics for Life Author trailer</a>&nbsp;(6:49)</li></ol><br><p></p>
# XXX Setting self.intro to None
# XXX Setting self.content to <p><strong>Browse through the CSE Syllabus.</strong><span> This syllabus is comprehensive.  It includes the (i) syllabus, (ii) course schedule, (iii) breakdown of points by assignment, quiz, discussion board, and exam, and (iv) course policy and procedures.  </span><br /><span></span></p>
# <p><span>In the syllabus, you will find key concepts for the modules and any supplemental units. Also included are the reading, video, and podcast assignments intended to help you understand the concepts and how to apply what you learn about them. In the course schedule, each graded discussion post, assignment, quiz, or exam is listed. This list identifies what is expected and when. The table showing the distribution of points identifies how many points are assigned to each course activity. As evidenced by the layout of this course, there are many, many links to national standards in economics and personal finance. On request, they will be identified.  </span></p>
# XXX Setting self.intro to None
# XXX Setting self.content to <p>Learn on the go!  In the future, there will be podcasts for your listening pleasure.  Each audio begins with an introductory question.  It ends with a concluding thought.  So get up and move about while you listen and learn.  PDF files are provided for those individuals who want to read along, learn to improve their reading skills if English is a learning language, or have difficulty hearing.  Enjoy!</p>
# section Module 00: First Day
#     page Objectives:  Module 00
#     quiz Start Line: Survey of Economic Reasoning
#     quiz Start Line: CSE 1001 Survey of Economic Reasoning
#     quiz Start Line: CSE 1002 Survey of Economic Reasoning
#     page Module 00: Course Background
#     page Watch: Module 00
#     page Read: Module 00
#     page Listen: Module 00
#     forum Do:  Discussion Board Module 0 Introductions (MODIFY and then delete this.)
#     forum Do: Discussion Board Module 01
# 'Module 00: First Day'

# %%
import uuid

class H5PCoursePresentation(object):
    def __init__(self,section,subDir=None,baseDir=export_dir):
        self._content = None
        self.mdlobj = section
        if subDir is None:
            subDir = section.title
        self.baseDir = os.path.join(baseDir,subDir)
        self.contentDir = os.path.join(self.baseDir,"content")
        self._populate_basedir()
        self._fetch_media()
        
    def _populate_basedir(self,force=False):
        print "XXX copying template to %s" % self.baseDir
        if not os.path.exists(self.baseDir) or force:
            copy(h5p_template_dirs["CoursePresentation"],self.baseDir)
    
    def _fetch_media(self,contentDir=None):
        if contentDir is None:
            contentDir = self.contentDir
        self.mdlobj.fetch_media(contentDir)
            
    @property
    def content(self):
        if self._content is None:
            self._content = self._generate_content()
        return self._content
    
    def _generate_content(self):
        content = {}
        content["presentation"] = {
            "slides": [ m.to_h5p(self.baseDir).content for m in self.xmlRoot.modules ]
            }
        content["l10n"] = {
            "slide": "Slide",
            "yourScore": "Your Score",
            "maxScore": "Max Score",
            "goodScore": "Congratulations! You got @percent correct!",
            "okScore": "Nice effort! You got @percent correct!",
            "badScore": "You got @percent correct.",
            "Total": "Total",
            "showSolutions": "Show solutions",
            "retry": "Retry",
            "title": "Title",
            "author": "Author",
            "lisence": "Lisence",
            "license": "License",
            "exportAnswers": "Export text",
            "copyright": "Rights of use",
            "hideKeywords": "Hide keywords list",
            "showKeywords": "Show keywords list",
            "fullscreen": "Fullscreen",
            "exitFullscreen": "Exit fullscreen",
            "prevSlide": "Previous slide",
            "nextSlide": "Next slide",
            "currentSlide": "Current slide",
            "lastSlide": "Last slide",
            "solutionModeTitle": "Exit solution mode",
            "solutionModeText": "Solution Mode",
            "summaryMultipleTaskText": "Multiple tasks",
            "scoreMessage": "You achieved:",
            "shareFacebook": "Share on Facebook",
            "shareTwitter": "Share on Twitter",
            "summary": "Summary",
            "solutionsButtonTitle": "Show comments",
            "printTitle": "Print",
            "printIngress": "How would you like to print this presentation?",
            "printAllSlides": "Print all slides",
            "printCurrentSlide": "Print current slide"
          }
        content["override"] = {
            "activeSurface": False,
            "overrideButtons": False,
            "overrideShowSolutionButton": False,
            "overrideRetry": False,
            "hideSummarySlide": False
          }
        self.content = content
        
    def __repr__(self):
        return json.dumps(self.content)
    
class H5PSlide(object):
    def __init__(self,mdlobj):
        self.content = {
            "elements": [
              {
                "x": 1,
                "y": 1,
                "width": 98,
                "height": 98,
                "action": {
                  "library": "H5P.AdvancedText 1.1",
                  "params": {
                    "text": getattr(mdlobj,"content","<h1>TODO</h1>")
                  },
                  "subContentId": str(uuid.uuid1())
                },
                "alwaysDisplayComments": False,
                "backgroundOpacity": 0,
                "displayAsButton": False,
                "invisible": False,
                "solution": ""
              }
            ],
            "keywords": []
          },
    def __repr__(self):
        return json.dumps(self.content)

# %%
# Factory function for generating an object of the appropriate class, 
# given the xml node of a Moodle <activity> from moodle_backup.xml
class UnknownMoodleModuleException(Exception):
    pass

def module_factory(module_xml):
    module_classes = {
        "assign": MoodleAssign,
        "folder" : MoodleFolder,
        "forum" : MoodleForum,
        "label" : MoodleLabel,
        "page"  : MoodlePage,
        "quiz"  : MoodleQuiz,
        "url"   : MoodleUrl,
    }
    modulename = module_xml.find("modulename").text
    if module_classes.has_key(modulename):
        return module_classes[modulename](module_xml)
    else: 
        raise UnknownMoodleModuleException("Don't know how to handle '%s' modules" % modulename)

# %% [markdown]
# # STATUS
# At this point, the script can load in all the sections and modules in a course, download any files that are referenced with regular links.
#
# # TODO:
# * Add special handling for video
# * Generate H5P json from moodle objects
# * Probably other things I'm not thinking of right now...

# %% [markdown]
# # From here down are experiments with tallying the number and types of questions in the quizzes
#
# They can be ignored unless you're curious about that.
#
# ## First, all questions in the question bank...

# %%
questions = lxml.etree.parse(moodle_dir + "questions.xml")
questions_by_id = {}
questions_by_qtype = {}
for q in questions.xpath("//question"):
    qid = q.get("id")
    questions_by_id[qid] = {}
    for prop in ["qtype","name","questiontext"]:
        questions_by_id[qid][prop] = q.findtext(prop)
    if not questions_by_qtype.has_key(questions_by_id[qid]["qtype"]):
        questions_by_qtype[questions_by_id[qid]["qtype"]] = []
    questions_by_qtype[questions_by_id[qid]["qtype"]].append(qid)
    
total = 0
for qtype,qlist in questions_by_qtype.items():
    total += len(qlist)
    print "%s:  %s" % (qtype,len(qlist))
print "TOTAL:  %s" % total

# %% [markdown]
# ## Another approach: read in all question refs from all quizzes, cross reference with questions_by_id, and  get the breakdown by type of the *used* questions.

# %%
import glob
used_questions_by_qtype = {}
for qfn in glob.glob(moodle_dir + "activities/quiz_*"):
    qxml = lxml.etree.parse(qfn+"/quiz.xml")
    for qid in [ q.text for q in qxml.xpath("//question_instance/questionid")]:
        qdata = questions_by_id[qid]
        if not used_questions_by_qtype.has_key(qdata["qtype"]):
            used_questions_by_qtype[qdata["qtype"]] = []
        used_questions_by_qtype[qdata["qtype"]].append(qid)   
        
total = 0
for qtype,qlist in used_questions_by_qtype.items():
    total += len(qlist)
    print "%s:  %s" % (qtype,len(qlist))
print "TOTAL:  %s" % total

# %%
print "Hello {%(name)s and %(blah)s} {}" % {"blah":"FOO","name":"BAR"}
